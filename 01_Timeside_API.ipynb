# %% [markdown]
# # TimeSide API

# %% [markdown]
# *Timeside* API is based on different core processing unit called *processors* :
#
# - Decoders (*timeside.api.IDecoder*) that enables to decode a giving audio source and split it up into frames for further processing
# - Analyzers (*timeside.api.IAnalyzer*) that provides some signal processing module to analyze incoming audio frames
# - Encoders (*timeside.api.IEncoder*) that can encode incoming frames back into an audio object
# - Graphers (*timeside.api.IGrapher*) that can display some representations of the signal or corresponding extracted features

# %% [markdown]
# ## Decoders

# %%
# %pylab inline
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 8  # that's default image size for this interactive session
import timeside

import timeside
from timeside.core import list_processors

list_processors(timeside.api.IDecoder)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# IDecoder
#   ArrayDecoder [array_dec]
#   FileDecoder [gst_dec]
#   LiveDecoder [gst_live_dec]
# WARNING: pylab import has clobbered these variables: ['specgram']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## Analyzers

# %%
list_processors(timeside.api.IAnalyzer)
# Out:
# IAnalyzer
#   IValueAnalyzer
#     MeanDCShift [mean_dc_shift]
#     Level [level]
#   VampSimpleHost [vamp_simple_host]
#   AubioMelEnergy [aubio_melenergy]
#   AubioMfcc [aubio_mfcc]
#   AubioPitch [aubio_pitch]
#   AubioSpecdesc [aubio_specdesc]
#   AubioTemporal [aubio_temporal]
#   Waveform [waveform_analyzer]
#   IRITDiverg [irit_diverg]
#   IRITMonopoly [irit_monopoly]
#   IRITMusicLDN [irit_music_ldn]
#   IRITMusicSLN [irit_music_sln]
#   IRITMusicSNB [irit_music_snb]
#   IRITStartSeg [irit_startseg]
#   IRITSpeech4Hz [irit_speech_4hz]
#   IRITSpeechEntropy [irit_speech_entropy]
#   LimsiSad [limsi_sad]
#   Spectrogram [spectrogram_analyzer]
#   OnsetDetectionFunction [odf]
#   Tempogram [tempogram]
#   Yaafe [yaafe]

# %% [markdown]
# ## Encoders

# %%
list_processors(timeside.api.IEncoder)
# Out:
# IEncoder
#   AudioSink [gst_audio_sink_enc]
#   FlacEncoder [gst_flac_enc]
#   AacEncoder [gst_aac_enc]
#   Mp3Encoder [gst_mp3_enc]
#   VorbisEncoder [gst_vorbis_enc]
#   OpusEncoder [gst_opus_enc]
#   WavEncoder [gst_wav_enc]
#   WebMEncoder [gst_webm_enc]

# %% [markdown]
# ## Graphers

# %%
list_processors(timeside.api.IGrapher)
# Out:
# IGrapher
#   Display.aubio_pitch.pitch [grapher_aubio_pitch]
#   Display.odf [grapher_odf]
#   Display.waveform_analyzer [grapher_waveform]
#   Display.irit_speech_4hz.segments [grapher_irit_speech_4hz_segments]
#   SpectrogramLog [spectrogram_log]
#   SpectrogramLinear [spectrogram_lin]
#   Waveform [waveform_simple]
#   WaveformCentroid [waveform_centroid]
#   WaveformContourBlack [waveform_contour_black]
#   WaveformContourWhite [waveform_contour_white]
#   WaveformTransparent [waveform_transparent]

# %% [markdown]
# ## Processors pipeline

# %% [markdown]
# All these processors can be chained to form a process pipeline.
#
# Let first define a decoder that reads and decodes audio from a file

# %%
from timeside.core import get_processor

file_decoder = get_processor('gst_dec')('/home/thomas/code/timeside/TimeSide/tests/samples/guitar.wav')

# %% [markdown]
# And then some other processors

# %%
# analyzers
pitch = get_processor('aubio_pitch')()
level = get_processor('level')()

# Encoder
mp3 = get_processor('gst_mp3_enc')('/tmp/guitar.mp3', overwrite=True)

# Graphers
specgram = get_processor('spectrogram_lin')()
waveform = get_processor('waveform_simple')()

# %% [markdown]
# Let's now define a process pipeline with all these processors and run it

# %%
pipe = (file_decoder | pitch | level | mp3 | specgram | waveform)
pipe.run()

# %% [markdown]
# Analyzers results are available through the pipe:

# %%
pipe.results.keys()
# Out:
# ['level.rms', 'level.max', 'aubio_pitch.pitch_confidence', 'aubio_pitch.pitch']

# %% [markdown]
# or from the analyzer:

# %%
pitch.results.keys()
# Out:
# ['aubio_pitch.pitch', 'aubio_pitch.pitch_confidence']

# %%
pitch.results['aubio_pitch.pitch'].keys()
# Out:
# ['id_metadata',
#  'data_object',
#  'audio_metadata',
#  'frame_metadata',
#  'parameters']

# %%
pitch.results['aubio_pitch.pitch']
# Out:
# FrameValueResult(id_metadata=IdMetadata(id='aubio_pitch.pitch', name='f0 (aubio) pitch', unit='Hz', description='', date='2014-06-12 00:35:15', version='0.5.6', author='TimeSide', uuid='358e2560-49ff-432d-bbe9-f3e278b5f4bc'), data_object=DataObject(value=array([ 124.76622772,  124.70761108,  125.05422974,  125.76716614,
#         125.28672791,  125.45233917,  125.41001129,  124.93823242,
#         139.237854  ,   61.45153427,  138.45236206,  125.44420624,
#         123.46033478,  122.77059174,  247.68533325,  247.44355774,
#         247.84062195,  247.67996216,  247.3572998 ,  247.20892334,
#         246.95826721,  246.86332703,  246.68986511,  246.51612854,
#         246.35842896,    0.        ,   56.41061783,  100.63993835,
#         102.11268616,  102.2598877 ,  102.77933502,  103.28891754,
#         103.15610504,   93.139328  ,   92.8353653 ,   96.57542419,
#          98.62527466,  124.39617157,  297.35824585,  299.05773926,
#         293.05422974,  292.14743042,  146.12303162,  291.54528809,
#         146.79568481,  146.88179016,  147.11070251,  147.04571533,
#         133.81538391,  123.7664566 ,  124.27397156,  250.90075684,
#         248.90663147,  248.484375  ,  248.4284668 ,  248.21942139,
#         247.88047791,  248.24320984,  241.87542725,  276.04016113,
#         120.05931854,  119.72705841,  252.83992004,  272.46038818,
#         273.3442688 ,  272.69506836,  272.91162109,  273.5723877 ,
#         276.03311157,  276.1293335 ,  118.45323944,  274.19049072,
#         273.88699341,  279.43109131,  271.79418945,  274.46792603,
#         282.15090942,  273.77890015,  274.34942627,  277.65420532,
#         110.34221649,  110.47815704,  110.32862854,   92.51663208,
#         103.30633545,  134.76925659,  136.29373169,  140.4964447 ,
#          49.47525024,  222.99699402,  222.70629883,  221.40229797,
#         111.76058197,  223.57044983,  224.51216125,  225.2015686 ,
#         225.45700073,  225.53590393,  225.5743866 ,  225.9387207 ,
#         225.89573669,  225.98475647,  226.01817322,  225.86709595,
#         226.37133789,  226.95202637,  227.26017761,  227.89990234,
#         227.91894531,  227.7651825 ,  227.67176819,  227.39189148,
#         227.4919281 ,  227.54376221,  227.92842102,  228.49234009,
#         142.25431824,  229.0978241 ,  228.7747345 ,  141.92694092,
#         141.71105957,  141.70932007,  141.91641235,  142.11735535,
#         142.46221924,  142.87268066,  143.04548645,  142.86178589,
#         142.89878845,  142.89439392,  143.03111267,  143.40930176,
#         143.87028503,  144.09761047,  144.26022339,  144.34635925,
#         144.28337097,  144.42449951,  144.58381653,  144.8631134 ,
#         145.24511719,  145.52886963,  111.39459991,  111.3459549 ,
#         111.37000275,  111.37731934,  111.32710266,  111.38896179,
#         111.30331421,  111.33413696,  111.33735657,  111.27690125,
#         111.36361694,  111.26144409,  111.30369568,  111.2949295 ,
#         111.25325775,  111.33280945,  111.25654602,  222.80218506,
#         222.77989197,  222.75202942,  222.91520691,  222.52330017,
#         220.91569519,  470.42077637,  111.26467133,  111.29660797,
#         111.27384186,  111.26905823,  111.30500031,  222.73617554,
#         222.91693115,  222.78601074,  222.71078491,  222.42280579,    0.        ], dtype=float32)), audio_metadata=AudioMetadata(uri='file:///home/thomas/code/timeside/TimeSide/tests/samples/guitar.wav', start=0.0, duration=4.128027211, is_segment=False, sha1='08301c3f9a8d60926f31e253825cc74263e52ad1', channels=1, channelsManagement=''), frame_metadata=FrameMetadata(samplerate=44100, blocksize=2048, stepsize=1024), parameters={})

# %% [markdown]
# Grapher result can also be display or save into a file

# %%
imshow(specgram.render(), origin='lower')

# %%
imshow(waveform.render(), origin='lower')

# %%
waveform.render('/tmp/waveform.png')

# %% [markdown]
# ## And TimeSide can be embedded into a web page dynamically. For example, in Telemeta:

# %%
from IPython.display import HTML
HTML('<iframe width=1300 height=260 frameborder=0 scrolling=no marginheight=0 marginwidth=0 src=http://demo.telemeta.org/archives/items/6/player/1200x170></iframe>')
# Out:
# <iframe width=1300 height=260 frameborder=0 scrolling=no marginheight=0 marginwidth=0 src=http://demo.telemeta.org/archives/items/6/player/1200x170></iframe>
